# %% [markdown]
# Проверим расчет с использованием класса BlackOilStanding c калибровками

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from neftpy.fluid import *

# %%
fl = Fluid_BlackOilStanding()
fl1 = Fluid_BlackOilStanding()
fl1.set_calibration(pb_calibr_atma=120, b_oilb_calibr_m3m3=1.2, mu_oilb_calibr_cP=1)

# %%
plist = np.linspace(1,300,100)
fl.calc(plist, 80)
fl1.calc(plist, 80)

# %%
plt.plot(plist, fl.b_oil_m3m3)
plt.plot(plist, fl1.b_oil_m3m3)

# %%
plt.plot(plist, fl.rs_m3m3)
plt.plot(plist, fl1.rs_m3m3)

# %%
plt.plot(plist, fl.rho_oil_kgm3)
plt.plot(plist, fl1.rho_oil_kgm3)

# %%
plt.plot(plist, fl.mu_oil_cP)
plt.plot(plist, fl1.mu_oil_cP)
