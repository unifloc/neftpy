# %% [markdown]
# Проверим расчет с использованием класса BlackOilStanding c калибровками

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from neftpy.fluid import *

# %%
fl = BlackOilStanding()

# %%
fl.calc(10, 80)

# %%
fl._rs_m3m3
# Out:
# array(2.80530625)

# %%
fl._b_oil_m3m3
# Out:
# np.float64(1.0609819887406324)

# %%
fl.calc(np.array([1,2,3]), 20 )

# %%
plist = np.linspace(1,300,100)

# %%
fl.calc(plist, 80)

# %%
plt.plot(plist, fl._b_oil_m3m3)
